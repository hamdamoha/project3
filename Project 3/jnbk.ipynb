# %%
# Dependencies
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
#base_url = "https://pokeapi.co/api/v2/pokemon/"

# %%
# Call the data from the api
def get_info():
    starter_lst = []
    for i in range(150):
        url = "https://pokeapi.co/api/v2/pokemon/"+str(i+1)
        response = requests.get(url).json()
        location = requests.get(response["location_area_encounters"]).json()

        if len(location) ==0:
            location="Whitechapel"
        else:
            location = location[0]["location_area"]["name"]
            # Initialise the data for the dataframe     

        starter_lst.append({
        "Pokemon name": response["name"],
        "Weight": response["weight"],
        "Fighting type" : response["types"][0]["type"]["name"],
        "Height": response["height"],
        "Main ability": response["abilities"][0]["ability"]["name"],
        "Attack": response["stats"][1]["base_stat"],
        "Defense": response["stats"][2]["base_stat"],
        "Type of Move":response["moves"][0]["move"]["name"],
        "Region": location
        })

        # Print the initial dataframe

    final_df = pd.DataFrame(starter_lst) 
    return (final_df)

# %%
final_df = get_info()
final_df
# Out:
#     Pokemon name  Weight Fighting type  Height Main ability  Attack  Defense  \
# 0      bulbasaur      69         grass       7     overgrow      49       49
# 1        ivysaur     130         grass      10     overgrow      62       63
# 2       venusaur    1000         grass      20     overgrow      82       83
# 3     charmander      85          fire       6        blaze      52       43
# 4     charmeleon     190          fire      11        blaze      64       58
# ..           ...     ...           ...     ...          ...     ...      ...
# 145      moltres     600          fire      20     pressure     100       90
# 146      dratini      33        dragon      18    shed-skin      64       45
# 147    dragonair     165        dragon      40    shed-skin      84       65
# 148    dragonite    2100        dragon      22  inner-focus     134       95
# 149       mewtwo    1220       psychic      20     pressure     110       90
#
#      Type of Move                      Region
# 0      razor-wind          cerulean-city-area
# 1    swords-dance                 Whitechapel
# 2    swords-dance                 Whitechapel
# 3      mega-punch            pallet-town-area
# 4      mega-punch                 Whitechapel
# ..            ...                         ...
# 145    razor-wind               mt-silver-top
# 146          bind               mt-coronet-4f
# 147          bind               mt-coronet-4f
# 148    mega-punch  dragonspiral-tower-outside
# 149    mega-punch           cerulean-cave-b1f
#
# [150 rows x 9 columns]

# %%
# Call the second api for the growth rate
import pprint

def get_growth_info ():
    base_url_2 = "https://pokeapi.co/api/v2/growth-rate/"

    lis_df=[]
    for i in range(1,7):
        url = "https://pokeapi.co/api/v2/growth-rate/"+str(i)+"/"
        response = requests.get(url).json()
        growth_lst = []
        
        for j in response["pokemon_species"]:
            growth_lst.append(j["name"])
            level_dic={"Growth Rate":[response["name"]]*len(growth_lst),"Pokemon name":growth_lst}
            
        lis_df.append(pd.DataFrame(level_dic)) 

    growth_df=pd.concat(lis_df)
    return (growth_df)

# %%
growth_df = get_growth_info()
growth_df
# Out:
#             Growth Rate Pokemon name
# 0                  slow    growlithe
# 1                  slow    tentacool
# 2                  slow     shellder
# 3                  slow    exeggcute
# 4                  slow      rhyhorn
# ..                  ...          ...
# 9   fast-then-very-slow     hariyama
# 10  fast-then-very-slow       swalot
# 11  fast-then-very-slow      wailord
# 12  fast-then-very-slow    crawdaunt
# 13  fast-then-very-slow     drifblim
#
# [1008 rows x 2 columns]

# %%
# Merge the growth rate dataframe and the initial dataframe
merge_df = pd.merge(final_df, growth_df, on="Pokemon name")
merge_df
# Out:
#     Pokemon name  Weight Fighting type  Height Main ability  Attack  Defense  \
# 0      bulbasaur      69         grass       7     overgrow      49       49
# 1        ivysaur     130         grass      10     overgrow      62       63
# 2       venusaur    1000         grass      20     overgrow      82       83
# 3     charmander      85          fire       6        blaze      52       43
# 4     charmeleon     190          fire      11        blaze      64       58
# ..           ...     ...           ...     ...          ...     ...      ...
# 145      moltres     600          fire      20     pressure     100       90
# 146      dratini      33        dragon      18    shed-skin      64       45
# 147    dragonair     165        dragon      40    shed-skin      84       65
# 148    dragonite    2100        dragon      22  inner-focus     134       95
# 149       mewtwo    1220       psychic      20     pressure     110       90
#
#      Type of Move                      Region  Growth Rate
# 0      razor-wind          cerulean-city-area  medium-slow
# 1    swords-dance                 Whitechapel  medium-slow
# 2    swords-dance                 Whitechapel  medium-slow
# 3      mega-punch            pallet-town-area  medium-slow
# 4      mega-punch                 Whitechapel  medium-slow
# ..            ...                         ...          ...
# 145    razor-wind               mt-silver-top         slow
# 146          bind               mt-coronet-4f         slow
# 147          bind               mt-coronet-4f         slow
# 148    mega-punch  dragonspiral-tower-outside         slow
# 149    mega-punch           cerulean-cave-b1f         slow
#
# [150 rows x 10 columns]

# %%
# Re-order the columns to tidy up ready for the merge with the co-ordinate data
reorder_df = merge_df.reindex(columns=['Pokemon name', 'Fighting type', 'Growth Rate', 'Main ability', 'Height', 'Weight', 'Attack', 'Defense', 'Type of Move', 'Region'])
reorder_df
# Out:
#     Pokemon name Fighting type  Growth Rate Main ability  Height  Weight  \
# 0      bulbasaur         grass  medium-slow     overgrow       7      69
# 1        ivysaur         grass  medium-slow     overgrow      10     130
# 2       venusaur         grass  medium-slow     overgrow      20    1000
# 3     charmander          fire  medium-slow        blaze       6      85
# 4     charmeleon          fire  medium-slow        blaze      11     190
# ..           ...           ...          ...          ...     ...     ...
# 145      moltres          fire         slow     pressure      20     600
# 146      dratini        dragon         slow    shed-skin      18      33
# 147    dragonair        dragon         slow    shed-skin      40     165
# 148    dragonite        dragon         slow  inner-focus      22    2100
# 149       mewtwo       psychic         slow     pressure      20    1220
#
#      Attack  Defense  Type of Move                      Region
# 0        49       49    razor-wind          cerulean-city-area
# 1        62       63  swords-dance                 Whitechapel
# 2        82       83  swords-dance                 Whitechapel
# 3        52       43    mega-punch            pallet-town-area
# 4        64       58    mega-punch                 Whitechapel
# ..      ...      ...           ...                         ...
# 145     100       90    razor-wind               mt-silver-top
# 146      64       45          bind               mt-coronet-4f
# 147      84       65          bind               mt-coronet-4f
# 148     134       95    mega-punch  dragonspiral-tower-outside
# 149     110       90    mega-punch           cerulean-cave-b1f
#
# [150 rows x 10 columns]

# %%
# Export to CSV to insert latitude and longitude for locations, and map to real world locations for the interactive map,
# call back into code for analysis
location_path = "location_with_lat_long.csv"

location_data = pd.read_csv(location_path)
location_data
# Out:
#     Pokemon name  Latitude  Longitude
# 0      bulbasaur    6.8428    81.3399
# 1        ivysaur   51.5148     0.0651
# 2       venusaur   51.5148     0.0651
# 3     charmander    7.2936    80.6413
# 4     charmeleon   51.5148     0.0651
# ..           ...       ...        ...
# 145      moltres   50.4155   -15.0737
# 146      dratini   39.9042   116.4074
# 147    dragonair   39.9042   116.4074
# 148    dragonite   50.3755    -4.1427
# 149       mewtwo   28.7041    77.1025
#
# [150 rows x 3 columns]

# %%
# Merge the dataframe with latitude and longitude to final_df
merged_df = pd.merge(reorder_df, location_data, on="Pokemon name", how ='left')
merged_df
# Out:
#     Pokemon name Fighting type  Growth Rate Main ability  Height  Weight  \
# 0      bulbasaur         grass  medium-slow     overgrow       7      69
# 1        ivysaur         grass  medium-slow     overgrow      10     130
# 2       venusaur         grass  medium-slow     overgrow      20    1000
# 3     charmander          fire  medium-slow        blaze       6      85
# 4     charmeleon          fire  medium-slow        blaze      11     190
# ..           ...           ...          ...          ...     ...     ...
# 145      moltres          fire         slow     pressure      20     600
# 146      dratini        dragon         slow    shed-skin      18      33
# 147    dragonair        dragon         slow    shed-skin      40     165
# 148    dragonite        dragon         slow  inner-focus      22    2100
# 149       mewtwo       psychic         slow     pressure      20    1220
#
#      Attack  Defense  Type of Move                      Region  Latitude  \
# 0        49       49    razor-wind          cerulean-city-area    6.8428
# 1        62       63  swords-dance                 Whitechapel   51.5148
# 2        82       83  swords-dance                 Whitechapel   51.5148
# 3        52       43    mega-punch            pallet-town-area    7.2936
# 4        64       58    mega-punch                 Whitechapel   51.5148
# ..      ...      ...           ...                         ...       ...
# 145     100       90    razor-wind               mt-silver-top   50.4155
# 146      64       45          bind               mt-coronet-4f   39.9042
# 147      84       65          bind               mt-coronet-4f   39.9042
# 148     134       95    mega-punch  dragonspiral-tower-outside   50.3755
# 149     110       90    mega-punch           cerulean-cave-b1f   28.7041
#
#      Longitude
# 0      81.3399
# 1       0.0651
# 2       0.0651
# 3      80.6413
# 4       0.0651
# ..         ...
# 145   -15.0737
# 146   116.4074
# 147   116.4074
# 148    -4.1427
# 149    77.1025
#
# [150 rows x 12 columns]

# %%
# Define the API endpoints for male, female, and genderless Pokemon
male_url = "https://pokeapi.co/api/v2/gender/1/"
female_url = "https://pokeapi.co/api/v2/gender/2/"
genderless_url = "https://pokeapi.co/api/v2/gender/3/"

# %%
# Define a function to get the name and gender of each Pokemon from a given API endpoint
def get_pokemon_gender(api_url, gender):
    response = requests.get(api_url)
    if response.status_code == 200:
        pokemon_list = response.json()["pokemon_species_details"]
        pokemon_names = [pokemon["pokemon_species"]["name"] for pokemon in pokemon_list]
        pokemon_genders = [response.json()["name"]]*len(pokemon_list)
        return pd.DataFrame({"Name": pokemon_names, "Gender": pokemon_genders})
    else:
        print(f"Error fetching data from {api_url}")

# %%
# Call the function for each API endpoint to get the male, female, and genderless Pokemon
male_df = get_pokemon_gender(male_url, "male")
female_df = get_pokemon_gender(female_url, "female")
genderless_df = get_pokemon_gender(genderless_url, "genderless")

# %%
# Concatenate the three dataframes into a single dataframe
pokemon_df = pd.concat([male_df, female_df, genderless_df])

# %%
# Print the resulting dataframe

pokemon1_df = pokemon_df.rename(columns={'Name': 'Pokemon name'})
pokemon1_df
# Out:
#     Pokemon name      Gender
# 0      bulbasaur      female
# 1     charmander      female
# 2       squirtle      female
# 3       caterpie      female
# 4         weedle      female
# ..           ...         ...
# 141       lunala  genderless
# 142    naganadel  genderless
# 143  polteageist  genderless
# 144     maushold  genderless
# 145    gholdengo  genderless
#
# [1811 rows x 2 columns]

# %%
# Rename female and male to genderless to avoid duplications in the data
pokemon1_df['Gender'] = pokemon1_df['Gender'].str.replace('female', 'genderless')
pokemon1_df['Gender'] = pokemon1_df['Gender'].str.replace('male', 'genderless')
second_merge_df = pd.merge(merged_df, pokemon1_df, on="Pokemon name", how ='left')
second_merge_df
# Out:
#     Pokemon name Fighting type  Growth Rate Main ability  Height  Weight  \
# 0      bulbasaur         grass  medium-slow     overgrow       7      69
# 1      bulbasaur         grass  medium-slow     overgrow       7      69
# 2        ivysaur         grass  medium-slow     overgrow      10     130
# 3        ivysaur         grass  medium-slow     overgrow      10     130
# 4       venusaur         grass  medium-slow     overgrow      20    1000
# ..           ...           ...          ...          ...     ...     ...
# 271    dragonair        dragon         slow    shed-skin      40     165
# 272    dragonair        dragon         slow    shed-skin      40     165
# 273    dragonite        dragon         slow  inner-focus      22    2100
# 274    dragonite        dragon         slow  inner-focus      22    2100
# 275       mewtwo       psychic         slow     pressure      20    1220
#
#      Attack  Defense  Type of Move                      Region  Latitude  \
# 0        49       49    razor-wind          cerulean-city-area    6.8428
# 1        49       49    razor-wind          cerulean-city-area    6.8428
# 2        62       63  swords-dance                 Whitechapel   51.5148
# 3        62       63  swords-dance                 Whitechapel   51.5148
# 4        82       83  swords-dance                 Whitechapel   51.5148
# ..      ...      ...           ...                         ...       ...
# 271      84       65          bind               mt-coronet-4f   39.9042
# 272      84       65          bind               mt-coronet-4f   39.9042
# 273     134       95    mega-punch  dragonspiral-tower-outside   50.3755
# 274     134       95    mega-punch  dragonspiral-tower-outside   50.3755
# 275     110       90    mega-punch           cerulean-cave-b1f   28.7041
#
#      Longitude      Gender
# 0      81.3399  genderless
# 1      81.3399  genderless
# 2       0.0651  genderless
# 3       0.0651  genderless
# 4       0.0651  genderless
# ..         ...         ...
# 271   116.4074  genderless
# 272   116.4074  genderless
# 273    -4.1427  genderless
# 274    -4.1427  genderless
# 275    77.1025  genderless
#
# [276 rows x 13 columns]

# %%
# Drop duplicates where Pokemon had genders, renumber index and keep change permanently
second_merge_df.drop_duplicates( keep='first', inplace=True, ignore_index=True)
second_merge_df
# Out:
#     Pokemon name Fighting type  Growth Rate Main ability  Height  Weight  \
# 0      bulbasaur         grass  medium-slow     overgrow       7      69
# 1        ivysaur         grass  medium-slow     overgrow      10     130
# 2       venusaur         grass  medium-slow     overgrow      20    1000
# 3     charmander          fire  medium-slow        blaze       6      85
# 4     charmeleon          fire  medium-slow        blaze      11     190
# ..           ...           ...          ...          ...     ...     ...
# 145      moltres          fire         slow     pressure      20     600
# 146      dratini        dragon         slow    shed-skin      18      33
# 147    dragonair        dragon         slow    shed-skin      40     165
# 148    dragonite        dragon         slow  inner-focus      22    2100
# 149       mewtwo       psychic         slow     pressure      20    1220
#
#      Attack  Defense  Type of Move                      Region  Latitude  \
# 0        49       49    razor-wind          cerulean-city-area    6.8428
# 1        62       63  swords-dance                 Whitechapel   51.5148
# 2        82       83  swords-dance                 Whitechapel   51.5148
# 3        52       43    mega-punch            pallet-town-area    7.2936
# 4        64       58    mega-punch                 Whitechapel   51.5148
# ..      ...      ...           ...                         ...       ...
# 145     100       90    razor-wind               mt-silver-top   50.4155
# 146      64       45          bind               mt-coronet-4f   39.9042
# 147      84       65          bind               mt-coronet-4f   39.9042
# 148     134       95    mega-punch  dragonspiral-tower-outside   50.3755
# 149     110       90    mega-punch           cerulean-cave-b1f   28.7041
#
#      Longitude      Gender
# 0      81.3399  genderless
# 1       0.0651  genderless
# 2       0.0651  genderless
# 3      80.6413  genderless
# 4       0.0651  genderless
# ..         ...         ...
# 145   -15.0737  genderless
# 146   116.4074  genderless
# 147   116.4074  genderless
# 148    -4.1427  genderless
# 149    77.1025  genderless
#
# [150 rows x 13 columns]

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///pokemon.sqlite")

# %%
second_merge_df.to_sql("pokemon", con=engine, if_exists='replace')
# Out:
# 150

# %%
df = pd.read_sql("select * from pokemon", con=engine)
df
# Out:
#      index Pokemon name Fighting type  Growth Rate Main ability  Height  \
# 0        0    bulbasaur         grass  medium-slow     overgrow       7
# 1        1      ivysaur         grass  medium-slow     overgrow      10
# 2        2     venusaur         grass  medium-slow     overgrow      20
# 3        3   charmander          fire  medium-slow        blaze       6
# 4        4   charmeleon          fire  medium-slow        blaze      11
# ..     ...          ...           ...          ...          ...     ...
# 145    145      moltres          fire         slow     pressure      20
# 146    146      dratini        dragon         slow    shed-skin      18
# 147    147    dragonair        dragon         slow    shed-skin      40
# 148    148    dragonite        dragon         slow  inner-focus      22
# 149    149       mewtwo       psychic         slow     pressure      20
#
#      Weight  Attack  Defense  Type of Move                      Region  \
# 0        69      49       49    razor-wind          cerulean-city-area
# 1       130      62       63  swords-dance                 Whitechapel
# 2      1000      82       83  swords-dance                 Whitechapel
# 3        85      52       43    mega-punch            pallet-town-area
# 4       190      64       58    mega-punch                 Whitechapel
# ..      ...     ...      ...           ...                         ...
# 145     600     100       90    razor-wind               mt-silver-top
# 146      33      64       45          bind               mt-coronet-4f
# 147     165      84       65          bind               mt-coronet-4f
# 148    2100     134       95    mega-punch  dragonspiral-tower-outside
# 149    1220     110       90    mega-punch           cerulean-cave-b1f
#
#      Latitude  Longitude      Gender
# 0      6.8428    81.3399  genderless
# 1     51.5148     0.0651  genderless
# 2     51.5148     0.0651  genderless
# 3      7.2936    80.6413  genderless
# 4     51.5148     0.0651  genderless
# ..        ...        ...         ...
# 145   50.4155   -15.0737  genderless
# 146   39.9042   116.4074  genderless
# 147   39.9042   116.4074  genderless
# 148   50.3755    -4.1427  genderless
# 149   28.7041    77.1025  genderless
#
# [150 rows x 14 columns]
